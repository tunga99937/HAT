# %%
# %cd drive/My\ Drive/Colab\ Notebooks/UCL-master
# Out:
# /content/drive/My Drive/Colab Notebooks/UCL-master

# %%
import torch
import numpy as np
a = np.log(np.exp(1) - 1)
b = torch.Tensor(3,3).uniform_(a, a)
c = (torch.ones(b.size())*(-1/2)).sum()
c
# Out:
# tensor(-4.5000)

# %%
# !python main.py --experiment 'pmnist' --approach si --c 0.03 --tasknum 10
# Out:
# ...
# Arguments =
# 	seed: 0
# 	experiment: pmnist
# 	approach: si
# 	optimizer: Adam
# 	ablation: None
# 	output:
# 	nepochs: 100
# 	unitN: 400
# 	batch_size: 256
# 	lr: 0.001
# 	lr_rho: 0.001
# 	ratio: 0.5
# 	alpha: 0.01
# 	beta: 0.03
# 	gamma: 0.75
# 	smax: 400
# 	lamb: 1.0
# 	c: 0.03
# 	date:
# 	tasknum: 10
# 	conv_net: False
# 	rebuttal: False
# 	parameter:
# 	sample: 1
# 	rho: -2.783
# ...
# Load data...
# 0,/usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:55: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:45: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:60: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# ...

# %% [markdown]
# function ClickConnect(){ console.log("Working"); document.querySelector("colab-toolbar-button#connect").click() } setInterval(ClickConnect,60000)
